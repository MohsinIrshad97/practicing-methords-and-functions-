# %%
class Fruit:
    '''OOPS BISMILLAH'''
    def __init__(self, name, nutrients):
        try:    
            assert type(nutrients)==list
        except AssertionError :
            print("invalid")
            raise Exception
        self.name = name
        self.nuts =nutrients
        self.ripe= False
    #now to create functions
    def get_name(self):
        return self.name 
    def get_nutrients(self):
        print(self.name, "the following are :")
        for value in self.nuts :
            print (value)
    def check_ripeness(self):
        return self.ripe 
    def ripenfruit (self):
        self.ripe = True

# %%
apple = Fruit(name ="apple", nutrients=["vit A", "vit b"])
banana = Fruit(name ="banana", nutrients = ["vit K", "K"])

# %%
banana.check_ripeness()
# Out:
# False

# %%
banana.ripenfruit()

# %%
banana.check_ripeness()
# Out:
# True
